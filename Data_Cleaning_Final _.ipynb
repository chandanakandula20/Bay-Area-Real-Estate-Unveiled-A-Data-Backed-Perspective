# %%
import numpy as np
import pandas as pd

# %%
# Read the CSV file
df = pd.read_csv("sale_prop_data.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2403 entries, 0 to 2402
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2403 non-null   int64
#  1   address                   2403 non-null   object
#  2   price                     2403 non-null   object
#  3   beds                      2403 non-null   object
#  4   baths                     2403 non-null   object
#  5   area                      2403 non-null   object
#  6   city                      2403 non-null   object
#  7   zipcode                   2403 non-null   int64
#  8   Time on Redfin            2065 non-null   object
#  9   Property Type             2403 non-null   object
#  10  Year Built                1871 non-null   float64
#  11  Community                 2327 non-null   object
#  12  Lot Size                  1759 non-null   object
#  13  List Price                2363 non-null   object
#  14  Est. Mo. Payment          2388 non-null   object
#  15  Redfin Estimate           1829 non-null   object
#  16  Price/Sq.Ft.              2290 non-null   object
#  17  Buyer’s Agent Commission  1565 non-null   object
#  18  HOA Dues                  697 non-null    object
#  19  Style                     962 non-null    object
#  20  Baths                     37 non-null     object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 394.4+ KB

# %%
df.head(10)
# Out:
#    Unnamed: 0                                   address       price beds  \
# 0           0        41247 Apricot Ln,Fremont, CA 94539  $1,999,888    4
# 1           1         34116 Pavia Ter,Fremont, CA 94555  $1,180,000    3
# 2           2            36778 Oak St,Fremont, CA 94536  $1,499,888    3
# 3           3     4046 Abbey Ter #113,Fremont, CA 94536    $598,500    2
# 4           4         345 Torrano Cmn,Fremont, CA 94536    $799,888    2
# 5           5        3374 Wolcott Cmn,FREMONT, CA 94538    $785,000    2
# 6           6         37955 Camden St,FREMONT, CA 94536  $1,100,000    3
# 7           7  3218 Winding Vista Cmn,Fremont, CA 94539  $3,550,000    4
# 8           8       4120 Woodcrest Dr,FREMONT, CA 94538  $1,399,000    3
# 9           9          5533 Azalea Way,NEWARK, CA 94560  $1,279,980    4
#
#   baths         area     city  zipcode Time on Redfin  \
# 0     2  1,698 Sq ft  Fremont    94539         5 days
# 1   3.5  1,387 Sq ft  Fremont    94555          1 day
# 2     2  1,610 Sq ft  Fremont    94536          1 day
# 3     2    823 Sq ft  Fremont    94536          1 day
# 4     1  1,016 Sq ft  Fremont    94536          1 day
# 5     2  1,280 Sq ft  Fremont    94538          1 day
# 6     2  1,530 Sq ft  Fremont    94536          1 day
# 7   3.5  3,442 Sq ft  Fremont    94539          1 day
# 8     2  1,120 Sq ft  Fremont    94538         2 days
# 9   3.5  2,026 Sq ft  Fremont    94560         2 days
#
#                Property Type  ...        Community       Lot Size  List Price  \
# 0  Single Family Residential  ...          FREMONT  6,720 Sq. Ft.  $1,999,888
# 1                      Condo  ...   ARDENWOOD AREA     0.91 Acres  $1,180,000
# 2  Single Family Residential  ...        FAIR OAKS  6,978 Sq. Ft.  $1,499,888
# 3                      Condo  ...     CENTRAL PARK     0.58 Acres    $598,500
# 4                  Townhouse  ...  NILES THE TREES  2,448 Sq. Ft.    $799,888
# 5                      Condo  ...          FREMONT            NaN    $785,000
# 6         Single Family Home  ...          FREMONT  6,237 Sq. Ft.  $1,100,000
# 7  Single Family Residential  ...    PONDEROSA HTS     0.55 Acres  $3,550,000
# 8         Single Family Home  ...          FREMONT  5,995 Sq. Ft.  $1,399,000
# 9              Condo (Co-op)  ...           NEWARK            NaN  $1,279,980
#
#   Est. Mo. Payment Redfin Estimate Price/Sq.Ft. Buyer’s Agent Commission  \
# 0          $14,526      $2,134,398       $1,178                     2.5%
# 1           $8,855      $1,161,551         $851                     2.5%
# 2          $10,894      $1,513,958         $932                     2.5%
# 3           $4,757        $598,791         $727                     2.5%
# 4           $6,150        $798,177         $787                     2.5%
# 5           $6,123        $784,377         $613                     2.5%
# 6           $8,023      $1,108,121         $719                     2.5%
# 7          $26,000      $3,553,718       $1,031                     2.5%
# 8          $10,162      $1,349,353       $1,249                     2.5%
# 9           $8,276      $1,269,155         $632                     2.5%
#
#      HOA Dues          Style Baths
# 0         NaN            NaN   NaN
# 1  $284/month   Contemporary   NaN
# 2         NaN          Ranch   NaN
# 3  $410/month   Contemporary   NaN
# 4  $340/month            NaN   NaN
# 5        $421            NaN   NaN
# 6         $33            NaN   NaN
# 7  $215/month  Mediterranean   NaN
# 8         NaN            NaN   NaN
# 9        $312            NaN   NaN
#
# [10 rows x 21 columns]

# %%
# Drop duplicate column
df = df.drop(columns=['Baths', 'List Price', 'Unnamed: 0'])
df
# Out:
#                                      address       price beds baths  \
# 0         41247 Apricot Ln,Fremont, CA 94539  $1,999,888    4     2
# 1          34116 Pavia Ter,Fremont, CA 94555  $1,180,000    3   3.5
# 2             36778 Oak St,Fremont, CA 94536  $1,499,888    3     2
# 3      4046 Abbey Ter #113,Fremont, CA 94536    $598,500    2     2
# 4          345 Torrano Cmn,Fremont, CA 94536    $799,888    2     1
# ...                                      ...         ...  ...   ...
# 2398  151 Wellington Ave,Daly City, CA 94014  $1,150,000    2     1
# 2399  127 Wellington Ave,Daly City, CA 94014    $850,000    2     1
# 2400    475 Irvington St,Daly City, CA 94014    $875,000    2     1
# 2401     68 Lausanne Ave,DALY CITY, CA 94014  $1,250,000    5     4
# 2402  139 Wellington Ave,Daly City, CA 94014    $670,000    —     —
#
#              area       city  zipcode Time on Redfin  \
# 0     1,698 Sq ft    Fremont    94539         5 days
# 1     1,387 Sq ft    Fremont    94555          1 day
# 2     1,610 Sq ft    Fremont    94536          1 day
# 3       823 Sq ft    Fremont    94536          1 day
# 4     1,016 Sq ft    Fremont    94536          1 day
# ...           ...        ...      ...            ...
# 2398    980 Sq ft  Daly City    94014       332 days
# 2399  1,270 Sq ft  Daly City    94014       332 days
# 2400    980 Sq ft  Daly City    94014       332 days
# 2401  4,348 Sq ft  Daly City    94014       375 days
# 2402  2,782 Sq ft  Daly City    94014       332 days
#
#                   Property Type  Year Built        Community       Lot Size  \
# 0     Single Family Residential      1960.0          FREMONT  6,720 Sq. Ft.
# 1                         Condo      2012.0   ARDENWOOD AREA     0.91 Acres
# 2     Single Family Residential      1961.0        FAIR OAKS  6,978 Sq. Ft.
# 3                         Condo      1986.0     CENTRAL PARK     0.58 Acres
# 4                     Townhouse      1975.0  NILES THE TREES  2,448 Sq. Ft.
# ...                         ...         ...              ...            ...
# 2398  Single Family Residential      1912.0        Daly City  3,597 Sq. Ft.
# 2399  Single Family Residential      1912.0        Daly City  3,094 Sq. Ft.
# 2400  Single Family Residential      1912.0        Daly City  1,850 Sq. Ft.
# 2401                    Triplex      1965.0        DALY CITY  2,500 Sq. Ft.
# 2402                Vacant Land         NaN        Daly City  2,782 Sq. Ft.
#
#      Est. Mo. Payment Redfin Estimate Price/Sq.Ft. Buyer’s Agent Commission  \
# 0             $14,526      $2,134,398       $1,178                     2.5%
# 1              $8,855      $1,161,551         $851                     2.5%
# 2             $10,894      $1,513,958         $932                     2.5%
# 3              $4,757        $598,791         $727                     2.5%
# 4              $6,150        $798,177         $787                     2.5%
# ...               ...             ...          ...                      ...
# 2398           $8,353      $1,082,742       $1,173                      NaN
# 2399           $6,174        $829,959         $669                      NaN
# 2400           $6,356        $842,589         $893                      NaN
# 2401           $9,079      $1,189,034         $287                     2.5%
# 2402           $4,867        $624,060          NaN                      NaN
#
#         HOA Dues               Style
# 0            NaN                 NaN
# 1     $284/month        Contemporary
# 2            NaN               Ranch
# 3     $410/month        Contemporary
# 4     $340/month                 NaN
# ...          ...                 ...
# 2398         NaN  Traditional, Other
# 2399         NaN  Traditional, Other
# 2400         NaN         Traditional
# 2401         NaN                 NaN
# 2402         NaN                 NaN
#
# [2403 rows x 18 columns]

# %%
# Rename columns
df.rename(columns={'address':'Address','price':'Price',
                      'beds':'Beds','baths':'Baths',
                      'area':'Area_Sqft','city':'City',
                      'zipcode':'Zipcode',
                      'Time on Redfin':'Time_on_Redfin(days)','Year Built':'Year_built',
                      'Community':'Community','Lot Size':'Lot_Size_Sqft','Est. Mo. Payment':'Est_Monthly_Payt',
                      'Redfin Estimate':'Est_Redfin_Price','Price/Sq.Ft':'Price/Sq.Ft','Buyer’s Agent Commission':'Buyer_Agent_Commission',
                      'HOA Dues':'HOA_Dues','Style':'Style'}, inplace=True)
df
# Out:
#                                      Address       Price Beds Baths  \
# 0         41247 Apricot Ln,Fremont, CA 94539  $1,999,888    4     2
# 1          34116 Pavia Ter,Fremont, CA 94555  $1,180,000    3   3.5
# 2             36778 Oak St,Fremont, CA 94536  $1,499,888    3     2
# 3      4046 Abbey Ter #113,Fremont, CA 94536    $598,500    2     2
# 4          345 Torrano Cmn,Fremont, CA 94536    $799,888    2     1
# ...                                      ...         ...  ...   ...
# 2398  151 Wellington Ave,Daly City, CA 94014  $1,150,000    2     1
# 2399  127 Wellington Ave,Daly City, CA 94014    $850,000    2     1
# 2400    475 Irvington St,Daly City, CA 94014    $875,000    2     1
# 2401     68 Lausanne Ave,DALY CITY, CA 94014  $1,250,000    5     4
# 2402  139 Wellington Ave,Daly City, CA 94014    $670,000    —     —
#
#         Area_Sqft       City  Zipcode Time_on_Redfin(days)  \
# 0     1,698 Sq ft    Fremont    94539               5 days
# 1     1,387 Sq ft    Fremont    94555                1 day
# 2     1,610 Sq ft    Fremont    94536                1 day
# 3       823 Sq ft    Fremont    94536                1 day
# 4     1,016 Sq ft    Fremont    94536                1 day
# ...           ...        ...      ...                  ...
# 2398    980 Sq ft  Daly City    94014             332 days
# 2399  1,270 Sq ft  Daly City    94014             332 days
# 2400    980 Sq ft  Daly City    94014             332 days
# 2401  4,348 Sq ft  Daly City    94014             375 days
# 2402  2,782 Sq ft  Daly City    94014             332 days
#
#                   Property Type  Year_built        Community  Lot_Size_Sqft  \
# 0     Single Family Residential      1960.0          FREMONT  6,720 Sq. Ft.
# 1                         Condo      2012.0   ARDENWOOD AREA     0.91 Acres
# 2     Single Family Residential      1961.0        FAIR OAKS  6,978 Sq. Ft.
# 3                         Condo      1986.0     CENTRAL PARK     0.58 Acres
# 4                     Townhouse      1975.0  NILES THE TREES  2,448 Sq. Ft.
# ...                         ...         ...              ...            ...
# 2398  Single Family Residential      1912.0        Daly City  3,597 Sq. Ft.
# 2399  Single Family Residential      1912.0        Daly City  3,094 Sq. Ft.
# 2400  Single Family Residential      1912.0        Daly City  1,850 Sq. Ft.
# 2401                    Triplex      1965.0        DALY CITY  2,500 Sq. Ft.
# 2402                Vacant Land         NaN        Daly City  2,782 Sq. Ft.
#
#      Est_Monthly_Payt Est_Redfin_Price Price/Sq.Ft. Buyer_Agent_Commission  \
# 0             $14,526       $2,134,398       $1,178                   2.5%
# 1              $8,855       $1,161,551         $851                   2.5%
# 2             $10,894       $1,513,958         $932                   2.5%
# 3              $4,757         $598,791         $727                   2.5%
# 4              $6,150         $798,177         $787                   2.5%
# ...               ...              ...          ...                    ...
# 2398           $8,353       $1,082,742       $1,173                    NaN
# 2399           $6,174         $829,959         $669                    NaN
# 2400           $6,356         $842,589         $893                    NaN
# 2401           $9,079       $1,189,034         $287                   2.5%
# 2402           $4,867         $624,060          NaN                    NaN
#
#         HOA_Dues               Style
# 0            NaN                 NaN
# 1     $284/month        Contemporary
# 2            NaN               Ranch
# 3     $410/month        Contemporary
# 4     $340/month                 NaN
# ...          ...                 ...
# 2398         NaN  Traditional, Other
# 2399         NaN  Traditional, Other
# 2400         NaN         Traditional
# 2401         NaN                 NaN
# 2402         NaN                 NaN
#
# [2403 rows x 18 columns]

# %%
# Check duplicate rows
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#                                         Address        Price Beds Baths  \
# 535                   Plan 1,San Jose, CA 95120  $2,608,000+    3   3.5
# 536                   Plan 3,San Jose, CA 95120  $2,833,000+    4   3.5
# 537                   Zinnia,Milpitas, CA 95035  $1,461,995+    3     3
# 538               Periwinkle,Milpitas, CA 95035  $1,461,995+    3   2.5
# 539                   Violet,Milpitas, CA 95035  $1,181,995+    3     3
# ..                                          ...          ...  ...   ...
# 770                   Plan 6,San Jose, CA 95119  $1,150,900+    3   3.5
# 771                   Plan 2,San Jose, CA 95119    $994,900+    2   2.5
# 772              The Welford,San Jose, CA 95124  $3,260,000+    5   5.5
# 773  The Ascot with 1 Br ADU,San Jose, CA 95124  $3,195,000+    4   4.5
# 774          5972 Quantum Lp,San Jose, CA 95123     $954,489    —     —
#
#        Area_Sqft      City  Zipcode Time_on_Redfin(days)  \
# 535  3,669 Sq ft  San Jose    95120                  NaN
# 536  3,603 Sq ft  San Jose    95120                  NaN
# 537  1,948 Sq ft  San Jose    95035                  NaN
# 538  1,948 Sq ft  San Jose    95035                  NaN
# 539  1,475 Sq ft  San Jose    95035                  NaN
# ..           ...       ...      ...                  ...
# 770  1,774 Sq ft  San Jose    95119                  NaN
# 771  1,355 Sq ft  San Jose    95119                  NaN
# 772  3,400 Sq ft  San Jose    95124                  NaN
# 773  3,208 Sq ft  San Jose    95124                  NaN
# 774      — Sq ft  San Jose    95123                  NaN
#
#                  Property Type  Year_built                Community  \
# 535  Single Family Residential         NaN          Almaden Heights
# 536  Single Family Residential         NaN          Almaden Heights
# 537                  Townhouse         NaN  Parkside at Tarob Court
# 538                  Townhouse         NaN  Parkside at Tarob Court
# 539                  Townhouse         NaN  Parkside at Tarob Court
# ..                         ...         ...                      ...
# 770                      Condo         NaN        Lotus at UrbanOak
# 771                      Condo         NaN        Lotus at UrbanOak
# 772  Single Family Residential         NaN  Rosewood at Camden Park
# 773  Single Family Residential         NaN  Rosewood at Camden Park
# 774                Condo/Co-op         NaN                      NaN
#
#     Lot_Size_Sqft Est_Monthly_Payt Est_Redfin_Price Price/Sq.Ft.  \
# 535           NaN          $18,943              NaN         $711
# 536           NaN          $20,577              NaN         $786
# 537           NaN          $10,619              NaN         $751
# 538           NaN          $10,619              NaN         $751
# 539           NaN           $8,585              NaN         $801
# ..            ...              ...              ...          ...
# 770           NaN           $8,359              NaN         $649
# 771           NaN           $7,226              NaN         $734
# 772           NaN          $23,679              NaN         $959
# 773           NaN          $23,207              NaN         $996
# 774           NaN              NaN         $954,489          NaN
#
#     Buyer_Agent_Commission HOA_Dues                    Style
# 535                    NaN      NaN                      NaN
# 536                    NaN      NaN                      NaN
# 537                    NaN      NaN                      NaN
# 538                    NaN      NaN                      NaN
# 539                    NaN      NaN                      NaN
# ..                     ...      ...                      ...
# 770                    NaN      NaN  CondoOnly,MasterPlanned
# 771                    NaN      NaN  CondoOnly,MasterPlanned
# 772                    NaN      NaN                      NaN
# 773                    NaN      NaN                      NaN
# 774                    NaN      NaN                      NaN
#
# [239 rows x 18 columns]

# %%
# Drop duplicate rows
df = df.drop_duplicates()
df
# Out:
#                                      Address       Price Beds Baths  \
# 0         41247 Apricot Ln,Fremont, CA 94539  $1,999,888    4     2
# 1          34116 Pavia Ter,Fremont, CA 94555  $1,180,000    3   3.5
# 2             36778 Oak St,Fremont, CA 94536  $1,499,888    3     2
# 3      4046 Abbey Ter #113,Fremont, CA 94536    $598,500    2     2
# 4          345 Torrano Cmn,Fremont, CA 94536    $799,888    2     1
# ...                                      ...         ...  ...   ...
# 2398  151 Wellington Ave,Daly City, CA 94014  $1,150,000    2     1
# 2399  127 Wellington Ave,Daly City, CA 94014    $850,000    2     1
# 2400    475 Irvington St,Daly City, CA 94014    $875,000    2     1
# 2401     68 Lausanne Ave,DALY CITY, CA 94014  $1,250,000    5     4
# 2402  139 Wellington Ave,Daly City, CA 94014    $670,000    —     —
#
#         Area_Sqft       City  Zipcode Time_on_Redfin(days)  \
# 0     1,698 Sq ft    Fremont    94539               5 days
# 1     1,387 Sq ft    Fremont    94555                1 day
# 2     1,610 Sq ft    Fremont    94536                1 day
# 3       823 Sq ft    Fremont    94536                1 day
# 4     1,016 Sq ft    Fremont    94536                1 day
# ...           ...        ...      ...                  ...
# 2398    980 Sq ft  Daly City    94014             332 days
# 2399  1,270 Sq ft  Daly City    94014             332 days
# 2400    980 Sq ft  Daly City    94014             332 days
# 2401  4,348 Sq ft  Daly City    94014             375 days
# 2402  2,782 Sq ft  Daly City    94014             332 days
#
#                   Property Type  Year_built        Community  Lot_Size_Sqft  \
# 0     Single Family Residential      1960.0          FREMONT  6,720 Sq. Ft.
# 1                         Condo      2012.0   ARDENWOOD AREA     0.91 Acres
# 2     Single Family Residential      1961.0        FAIR OAKS  6,978 Sq. Ft.
# 3                         Condo      1986.0     CENTRAL PARK     0.58 Acres
# 4                     Townhouse      1975.0  NILES THE TREES  2,448 Sq. Ft.
# ...                         ...         ...              ...            ...
# 2398  Single Family Residential      1912.0        Daly City  3,597 Sq. Ft.
# 2399  Single Family Residential      1912.0        Daly City  3,094 Sq. Ft.
# 2400  Single Family Residential      1912.0        Daly City  1,850 Sq. Ft.
# 2401                    Triplex      1965.0        DALY CITY  2,500 Sq. Ft.
# 2402                Vacant Land         NaN        Daly City  2,782 Sq. Ft.
#
#      Est_Monthly_Payt Est_Redfin_Price Price/Sq.Ft. Buyer_Agent_Commission  \
# 0             $14,526       $2,134,398       $1,178                   2.5%
# 1              $8,855       $1,161,551         $851                   2.5%
# 2             $10,894       $1,513,958         $932                   2.5%
# 3              $4,757         $598,791         $727                   2.5%
# 4              $6,150         $798,177         $787                   2.5%
# ...               ...              ...          ...                    ...
# 2398           $8,353       $1,082,742       $1,173                    NaN
# 2399           $6,174         $829,959         $669                    NaN
# 2400           $6,356         $842,589         $893                    NaN
# 2401           $9,079       $1,189,034         $287                   2.5%
# 2402           $4,867         $624,060          NaN                    NaN
#
#         HOA_Dues               Style
# 0            NaN                 NaN
# 1     $284/month        Contemporary
# 2            NaN               Ranch
# 3     $410/month        Contemporary
# 4     $340/month                 NaN
# ...          ...                 ...
# 2398         NaN  Traditional, Other
# 2399         NaN  Traditional, Other
# 2400         NaN         Traditional
# 2401         NaN                 NaN
# 2402         NaN                 NaN
#
# [2164 rows x 18 columns]

# %%
# Dealing with missing values

# %%
# Check for '—' in the DataFrame
contains_dash = df.apply(lambda x: x.astype(str).str.contains('—')).any()

# Print columns that contain '—'
columns_with_dash = contains_dash[contains_dash == True].index.tolist()
print("Columns containing '—':", columns_with_dash)
# Out:
# Columns containing '—': ['Price', 'Beds', 'Baths', 'Area_Sqft']

# %%
# Count occurrences of '—' in the specified column for each row
dash_row_counts = df[df['Price'].astype(str).str.contains('—')].shape[0]
print("Number of rows with '—' in the", 'Price', "column:", dash_row_counts)

dash_row_counts = df[df['Beds'].astype(str).str.contains('—')].shape[0]
print("Number of rows with '—' in the", 'Beds', "column:", dash_row_counts)

dash_row_counts = df[df['Baths'].astype(str).str.contains('—')].shape[0]
print("Number of rows with '—' in the", 'Baths', "column:", dash_row_counts)

dash_row_counts = df[df['Area_Sqft'].astype(str).str.contains('—')].shape[0]
print("Number of rows with '—' in the", 'Area_Sqft', "column:", dash_row_counts)
# Out:
# Number of rows with '—' in the Price column: 1
# Number of rows with '—' in the Beds column: 218
# Number of rows with '—' in the Baths column: 255
# Number of rows with '—' in the Area_Sqft column: 32

# %%
# Replace '—' with 0
df['Price'] = df['Price'].str.replace('—', '0')
df['Beds'] = df['Beds'].str.replace('—', '0')
df['Baths'] = df['Baths'].str.replace('—', '0')
df['Area_Sqft'] = df['Area_Sqft'].str.replace('—', '0')
# Out:
# /var/folders/f4/x9b2p2t11s59gnlnjzbvsr940000gn/T/ipykernel_20726/878939208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df['Price'].str.replace('—', '0')
# /var/folders/f4/x9b2p2t11s59gnlnjzbvsr940000gn/T/ipykernel_20726/878939208.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Beds'] = df['Beds'].str.replace('—', '0')
# /var/folders/f4/x9b2p2t11s59gnlnjzbvsr940000gn/T/ipykernel_20726/878939208.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Baths'] = df['Baths'].str.replace('—', '0')
# /var/folders/f4/x9b2p2t11s59gnlnjzbvsr940000gn/T/ipykernel_20726/878939208.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Area_Sqft'] = df['Area_Sqft'].str.replace('—', '0')

# %%
# Missing values in df
df.isnull().sum()
# Out:
# Address                      0
# Price                        0
# Beds                         0
# Baths                        0
# Area_Sqft                    0
# City                         0
# Zipcode                      0
# Time_on_Redfin(days)       106
# Property Type                0
# Year_built                 300
# Community                   68
# Lot_Size_Sqft              405
# Est_Monthly_Payt             7
# Est_Redfin_Price           350
# Price/Sq.Ft.               105
# Buyer_Agent_Commission     606
# HOA_Dues                  1467
# Style                     1258
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2164 entries, 0 to 2402
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Address                 2164 non-null   object
#  1   Price                   2164 non-null   object
#  2   Beds                    2164 non-null   object
#  3   Baths                   2164 non-null   object
#  4   Area_Sqft               2164 non-null   object
#  5   City                    2164 non-null   object
#  6   Zipcode                 2164 non-null   int64
#  7   Time_on_Redfin(days)    2058 non-null   object
#  8   Property Type           2164 non-null   object
#  9   Year_built              1864 non-null   float64
#  10  Community               2096 non-null   object
#  11  Lot_Size_Sqft           1759 non-null   object
#  12  Est_Monthly_Payt        2157 non-null   object
#  13  Est_Redfin_Price        1814 non-null   object
#  14  Price/Sq.Ft.            2059 non-null   object
#  15  Buyer_Agent_Commission  1558 non-null   object
#  16  HOA_Dues                697 non-null    object
#  17  Style                   906 non-null    object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 321.2+ KB

# %%
# Check if Area_Sqft equal to 0
zero_area_rows = df[df['Area_Sqft'] == '0 Sq ft']
zero_area_rows
# Out:
#                                                Address        Price Beds  \
# 58                36341 Mission Blvd,FREMONT, CA 94536   $4,950,000    0
# 127                41223 Roberts Ave,FREMONT, CA 94538   $5,200,000    0
# 182    1918 Kilowatt Way Unit 302 F2,Fremont, CA 94539   $1,515,615    0
# 184        45258 Tom Blalock St #403,Fremont, CA 94539   $1,218,169    0
# 533                 5972 Quantum Lp,San Jose, CA 95123     $954,489    0
# 778                  794 Overhill Dr,HAYWARD, CA 94544   $1,795,000    0
# 789                 22811 Vermont St,Hayward, CA 94541       $1,000    0
# 861                     70 Barnes Ct,Hayward, CA 94544     $539,500    2
# 876               32513 Mission Blvd,Hayward, CA 94544   $1,995,000    0
# 897              25730 University Ct,HAYWARD, CA 94542   $7,200,000    0
# 940               32513 Mission Blvd,Hayward, CA 94544   $1,995,000    0
# 1006                 0 Miramonte,SAN LEANDRO, CA 94578   $1,188,888    0
# 1097            Undisclosed Address,Berkeley, CA 94703   $7,500,000    0
# 1216              6500 San Pablo Ave,OAKLAND, CA 94608   $1,350,000    0
# 1423                     420 5th St,Richmond, CA 94801     $867,841    0
# 1472             55 Brookdale Ave,San Rafael, CA 94901   $1,595,000    4
# 1479                39 Vendola Dr,San Rafael, CA 94903   $1,495,000    3
# 1567  11 Commodore Marina Unit A,Out Of Area, CA 94941     $525,000    1
# 1592            140 Edgewood Ave,Mill Valley, CA 94941   $9,975,000    5
# 1629         11 Commodore Marina,Out Of Area, CA 94941   $2,500,000    4
# 1640               9 Issaquah Dock,Sausalito, CA 94965     $775,000    1
# 1641              10 Issaquah Dock,Sausalito, CA 94965     $875,000    1
# 1642                  2 White Way,Muir Beach, CA 94965   $1,950,000    2
# 1649                     14 E Pier,Sausalito, CA 94965     $805,000    2
# 1730        620 - 620 Rollingwood Dr,Vallejo, CA 94591     $519,000    3
# 1791                         N/A N/A,VALLEJO, CA 94591     $160,000    0
# 1914            760 San Antonio Rd,PALO ALTO, CA 94303  $10,500,000    0
# 1993            760 San Antonio Rd,PALO ALTO, CA 94303  $10,500,000    0
# 2004        1893 Woodland Ave,EAST PALO ALTO, CA 94303   $7,999,888    0
# 2119         110-150 Charter St,REDWOOD CITY, CA 94061  $34,000,000    0
# 2287                960 Larkspur Dr,MILLBRAE, CA 94030     $699,000    0
# 2390                 0 Crocker Ave,DALY CITY, CA 94014   $1,600,000    0
#
#      Baths Area_Sqft           City  Zipcode Time_on_Redfin(days)  \
# 58       0   0 Sq ft        Fremont    94536              17 days
# 127      0   0 Sq ft        Fremont    94538             117 days
# 182      0   0 Sq ft        Fremont    94539                  NaN
# 184      0   0 Sq ft        Fremont    94539                  NaN
# 533      0   0 Sq ft       San Jose    95123                  NaN
# 778      0   0 Sq ft        Hayward    94544                1 day
# 789      0   0 Sq ft        Hayward    94541               3 days
# 861      1   0 Sq ft        Hayward    94544              37 days
# 876      0   0 Sq ft        Hayward    94544              47 days
# 897      0   0 Sq ft        Hayward    94542             122 days
# 940      0   0 Sq ft     Union City    94544              47 days
# 1006     0   0 Sq ft    San Leandro    94578              64 days
# 1097     0   0 Sq ft       Berkeley    94703               5 days
# 1216     0   0 Sq ft       Berkeley    94608             394 days
# 1423     0   0 Sq ft       Richmond    94801                  NaN
# 1472     4   0 Sq ft     San Rafael    94901              26 days
# 1479     2   0 Sq ft     San Rafael    94903              32 days
# 1567     1   0 Sq ft    Mill Valley    94941                1 day
# 1592     5   0 Sq ft    Mill Valley    94941              29 days
# 1629     4   0 Sq ft      Sausalito    94941                1 day
# 1640     1   0 Sq ft      Sausalito    94965              29 days
# 1641     1   0 Sq ft      Sausalito    94965              29 days
# 1642     2   0 Sq ft      Sausalito    94965              29 days
# 1649     1   0 Sq ft      Sausalito    94965              44 days
# 1730     2   0 Sq ft        Vallejo    94591              21 days
# 1791     0   0 Sq ft        Vallejo    94591              49 days
# 1914     0   0 Sq ft  Mountain View    94303             116 days
# 1993     0   0 Sq ft      Palo Alto    94303             116 days
# 2004     0   0 Sq ft      Palo Alto    94303             537 days
# 2119     0   0 Sq ft   Redwood City    94061             269 days
# 2287     0   0 Sq ft       Millbrae    94030             285 days
# 2390     0   0 Sq ft      Daly City    94014              89 days
#
#                      Property Type  Year_built           Community  \
# 58    Residential Development Land         NaN             FREMONT
# 127   Residential Development Land         NaN             FREMONT
# 182                    Condo/Co-op         NaN                 NaN
# 184                    Condo/Co-op         NaN                 NaN
# 533                    Condo/Co-op         NaN                 NaN
# 778   Residential Development Land         NaN             HAYWARD
# 789         Multi-Family (5+ Unit)         NaN             Hayward
# 861        Multi-Family (2-4 Unit)      1952.0             Hayward
# 876         Multi-Family (5+ Unit)      1958.0             Hayward
# 897   Residential Development Land         NaN             HAYWARD
# 940         Multi-Family (5+ Unit)      1958.0             Hayward
# 1006  Residential Development Land         NaN         SAN LEANDRO
# 1097        Multi-Family (5+ Unit)         NaN                 NaN
# 1216  Residential Development Land         NaN             OAKLAND
# 1423       Multi-Family (2-4 Unit)         NaN                 NaN
# 1472        Multi-Family (5+ Unit)         NaN          San Rafael
# 1479     Single Family Residential      1943.0       Santa Venetia
# 1567               B, Multi-Family      1975.0                 NaN
# 1592     Single Family Residential         NaN         Mill Valley
# 1629               B, Multi-Family      1975.0                 NaN
# 1640      Mobile/Manufactured Home      1979.0  Waldo Point Harbor
# 1641      Mobile/Manufactured Home      1979.0  Waldo Point Harbor
# 1642     Single Family Residential      1970.0          Muir Beach
# 1649      Mobile/Manufactured Home      1972.0       Kappas Marina
# 1730     Single Family Residential      1940.0             Vallejo
# 1791  Residential Development Land         NaN             VALLEJO
# 1914  Residential Development Land         NaN           PALO ALTO
# 1993  Residential Development Land         NaN           PALO ALTO
# 2004  Residential Development Land         NaN      EAST PALO ALTO
# 2119  Residential Development Land         NaN        REDWOOD CITY
# 2287  Residential Development Land         NaN            MILLBRAE
# 2390  Residential Development Land         NaN           DALY CITY
#
#        Lot_Size_Sqft Est_Monthly_Payt Est_Redfin_Price Price/Sq.Ft.  \
# 58        0.79 Acres          $35,954              NaN          NaN
# 127        0.9 Acres          $37,770              NaN          NaN
# 182              NaN              NaN       $1,515,615          NaN
# 184              NaN              NaN       $1,218,169          NaN
# 533              NaN              NaN         $954,489          NaN
# 778        0.8 Acres          $13,038              NaN          NaN
# 789       3.68 Acres               $7              NaN          NaN
# 861    6,675 Sq. Ft.           $3,919         $576,633          NaN
# 876              NaN          $14,491              NaN          NaN
# 897       2.72 Acres          $52,297              NaN          NaN
# 940              NaN          $14,491              NaN          NaN
# 1006      0.43 Acres           $9,185              NaN          NaN
# 1097      0.31 Acres          $54,476              NaN          NaN
# 1216   3,999 Sq. Ft.           $9,806              NaN          NaN
# 1423             NaN              NaN         $867,841          NaN
# 1472   5,715 Sq. Ft.          $11,585              NaN          NaN
# 1479  10,402 Sq. Ft.          $10,859       $1,452,960          NaN
# 1567   2,261 Sq. Ft.           $3,813              NaN          NaN
# 1592      0.77 Acres          $72,453              NaN          NaN
# 1629     435 Sq. Ft.          $18,159       $2,481,874          NaN
# 1640     584 Sq. Ft.           $5,629         $768,369          NaN
# 1641     584 Sq. Ft.           $6,356         $868,398          NaN
# 1642      0.82 Acres          $14,164              NaN          NaN
# 1649     584 Sq. Ft.           $5,847         $788,467          NaN
# 1730             NaN           $3,770         $519,307          NaN
# 1791      0.33 Acres           $1,171              NaN          NaN
# 1914      0.67 Acres          $76,266              NaN          NaN
# 1993      0.67 Acres          $76,266              NaN          NaN
# 2004      1.12 Acres          $58,107              NaN          NaN
# 2119      1.71 Acres         $246,957              NaN          NaN
# 2287       4.6 Acres           $5,077              NaN          NaN
# 2390      0.46 Acres          $11,622              NaN          NaN
#
#      Buyer_Agent_Commission HOA_Dues                Style
# 58                       2%      NaN                  NaN
# 127                    2.5%      NaN                  NaN
# 182                     NaN      NaN                  NaN
# 184                     NaN      NaN                  NaN
# 533                     NaN      NaN                  NaN
# 778                    2.5%      NaN                  NaN
# 789                     NaN      NaN                  NaN
# 861                     NaN      NaN         Contemporary
# 876                      2%      NaN                  NaN
# 897                      2%      NaN                  NaN
# 940                      2%      NaN                  NaN
# 1006                   2.5%     $550                  NaN
# 1097                    NaN      NaN       A-Frame, Other
# 1216                   2.5%      NaN                  NaN
# 1423                    NaN      NaN                  NaN
# 1472                    NaN      NaN                  NaN
# 1479                    NaN      NaN  Conversion, Cottage
# 1567                   2.5%      NaN                  NaN
# 1592                    NaN      NaN     Modern/High Tech
# 1629                   2.5%      NaN                  NaN
# 1640                    NaN      NaN                  NaN
# 1641                    NaN      NaN                  NaN
# 1642                    NaN      NaN   Mid-Century, Other
# 1649                    NaN      NaN                  NaN
# 1730                    NaN      NaN                  NaN
# 1791                     2%       $9                  NaN
# 1914                   1.5%      NaN                  NaN
# 1993                   1.5%      NaN                  NaN
# 2004                   1.5%      NaN                  NaN
# 2119                     2%      NaN                  NaN
# 2287                     3%      NaN                  NaN
# 2390                   2.5%      NaN                  NaN

# %%
# Remove rows with Area_Sqft equal to 0
df = df[df['Area_Sqft'] != '0 Sq ft']

# Reset the index if needed
df = df.reset_index(drop=True)
df
# Out:
#                                      Address       Price Beds Baths  \
# 0         41247 Apricot Ln,Fremont, CA 94539  $1,999,888    4     2
# 1          34116 Pavia Ter,Fremont, CA 94555  $1,180,000    3   3.5
# 2             36778 Oak St,Fremont, CA 94536  $1,499,888    3     2
# 3      4046 Abbey Ter #113,Fremont, CA 94536    $598,500    2     2
# 4          345 Torrano Cmn,Fremont, CA 94536    $799,888    2     1
# ...                                      ...         ...  ...   ...
# 2127  151 Wellington Ave,Daly City, CA 94014  $1,150,000    2     1
# 2128  127 Wellington Ave,Daly City, CA 94014    $850,000    2     1
# 2129    475 Irvington St,Daly City, CA 94014    $875,000    2     1
# 2130     68 Lausanne Ave,DALY CITY, CA 94014  $1,250,000    5     4
# 2131  139 Wellington Ave,Daly City, CA 94014    $670,000    0     0
#
#         Area_Sqft       City  Zipcode Time_on_Redfin(days)  \
# 0     1,698 Sq ft    Fremont    94539               5 days
# 1     1,387 Sq ft    Fremont    94555                1 day
# 2     1,610 Sq ft    Fremont    94536                1 day
# 3       823 Sq ft    Fremont    94536                1 day
# 4     1,016 Sq ft    Fremont    94536                1 day
# ...           ...        ...      ...                  ...
# 2127    980 Sq ft  Daly City    94014             332 days
# 2128  1,270 Sq ft  Daly City    94014             332 days
# 2129    980 Sq ft  Daly City    94014             332 days
# 2130  4,348 Sq ft  Daly City    94014             375 days
# 2131  2,782 Sq ft  Daly City    94014             332 days
#
#                   Property Type  Year_built        Community  Lot_Size_Sqft  \
# 0     Single Family Residential      1960.0          FREMONT  6,720 Sq. Ft.
# 1                         Condo      2012.0   ARDENWOOD AREA     0.91 Acres
# 2     Single Family Residential      1961.0        FAIR OAKS  6,978 Sq. Ft.
# 3                         Condo      1986.0     CENTRAL PARK     0.58 Acres
# 4                     Townhouse      1975.0  NILES THE TREES  2,448 Sq. Ft.
# ...                         ...         ...              ...            ...
# 2127  Single Family Residential      1912.0        Daly City  3,597 Sq. Ft.
# 2128  Single Family Residential      1912.0        Daly City  3,094 Sq. Ft.
# 2129  Single Family Residential      1912.0        Daly City  1,850 Sq. Ft.
# 2130                    Triplex      1965.0        DALY CITY  2,500 Sq. Ft.
# 2131                Vacant Land         NaN        Daly City  2,782 Sq. Ft.
#
#      Est_Monthly_Payt Est_Redfin_Price Price/Sq.Ft. Buyer_Agent_Commission  \
# 0             $14,526       $2,134,398       $1,178                   2.5%
# 1              $8,855       $1,161,551         $851                   2.5%
# 2             $10,894       $1,513,958         $932                   2.5%
# 3              $4,757         $598,791         $727                   2.5%
# 4              $6,150         $798,177         $787                   2.5%
# ...               ...              ...          ...                    ...
# 2127           $8,353       $1,082,742       $1,173                    NaN
# 2128           $6,174         $829,959         $669                    NaN
# 2129           $6,356         $842,589         $893                    NaN
# 2130           $9,079       $1,189,034         $287                   2.5%
# 2131           $4,867         $624,060          NaN                    NaN
#
#         HOA_Dues               Style
# 0            NaN                 NaN
# 1     $284/month        Contemporary
# 2            NaN               Ranch
# 3     $410/month        Contemporary
# 4     $340/month                 NaN
# ...          ...                 ...
# 2127         NaN  Traditional, Other
# 2128         NaN  Traditional, Other
# 2129         NaN         Traditional
# 2130         NaN                 NaN
# 2131         NaN                 NaN
#
# [2132 rows x 18 columns]

# %%
# Check for rows with both "Beds" and "Baths" equal to 0
zero_beds_baths = df[(df['Beds'] == '0') & (df['Baths'] == '0')]
zero_beds_baths
# Out:
#                                          Address       Price Beds Baths  \
# 95          36990 Mission Blvd,Fremont, CA 94536  $5,500,000    0     0
# 110         2381 Rutherford Ln,Fremont, CA 94539  $2,360,000    0     0
# 120          997 Old Canyon Rd,FREMONT, CA 94536  $1,153,000    0     0
# 121               3275 Capitol,Fremont, CA 94538  $9,990,000    0     0
# 132              816 Hunter Ln,Fremont, CA 94539  $3,300,000    0     0
# ...                                          ...         ...  ...   ...
# 2086            85 Orange Ct,Daly City, CA 94014    $599,000    0     0
# 2096           20 Skyline Dr,Daly City, CA 94015    $450,000    0     0
# 2103  0 Cashlea Ct,South San Francisco, CA 94080          $1    0     0
# 2125   95 Santa Cruz Ave,San Francisco, CA 94112    $620,000    0     0
# 2131      139 Wellington Ave,Daly City, CA 94014    $670,000    0     0
#
#          Area_Sqft       City  Zipcode Time_on_Redfin(days)  \
# 95    10,729 Sq ft    Fremont    94536              50 days
# 110     0.50 Sq ft    Fremont    94539              60 days
# 120     0.37 Sq ft    Fremont    94536              85 days
# 121     0.87 Sq ft    Fremont    94538              99 days
# 132     0.62 Sq ft    Fremont    94539             365 days
# ...            ...        ...      ...                  ...
# 2086    0.35 Sq ft  Daly City    94014              25 days
# 2096   3,900 Sq ft  Daly City    94015              34 days
# 2103   2,660 Sq ft  Daly City    94080              41 days
# 2125   1,999 Sq ft  Daly City    94112             220 days
# 2131   2,782 Sq ft  Daly City    94014             332 days
#
#                Property Type  Year_built            Community  Lot_Size_Sqft  \
# 95    Multi-Family (5+ Unit)      1900.0              Fremont       20 Acres
# 110              Vacant Land         NaN     VINEYARD HEIGHTS      0.5 Acres
# 120          Residential Lot         NaN              FREMONT     0.37 Acres
# 121              Vacant Land         NaN              Fremont     0.87 Acres
# 132              Vacant Land         NaN     MISSION FOOTHILL     0.62 Acres
# ...                      ...         ...                  ...            ...
# 2086             Vacant Land         NaN            Daly City     0.35 Acres
# 2096             Vacant Land         NaN            Daly City  3,900 Sq. Ft.
# 2103             Vacant Land         NaN  South San Francisco  2,660 Sq. Ft.
# 2125             Vacant Land         NaN        San Francisco  1,999 Sq. Ft.
# 2131             Vacant Land         NaN            Daly City  2,782 Sq. Ft.
#
#      Est_Monthly_Payt Est_Redfin_Price Price/Sq.Ft. Buyer_Agent_Commission  \
# 95            $39,949              NaN         $513                     2%
# 110           $17,307       $2,263,011         $109                   2.5%
# 120            $8,375       $1,091,739          NaN                   2.5%
# 121           $73,062       $9,132,954         $262                     2%
# 132           $23,969       $3,042,919         $122                     1%
# ...               ...              ...          ...                    ...
# 2086           $4,351         $589,650          NaN                    NaN
# 2096           $3,269         $410,805          NaN                    NaN
# 2103               $0              NaN          NaN                    NaN
# 2125           $4,503         $579,295          NaN                    NaN
# 2131           $4,867         $624,060          NaN                    NaN
#
#         HOA_Dues Style
# 95           NaN   NaN
# 110   $165/month   NaN
# 120          NaN   NaN
# 121   $500/month   NaN
# 132          NaN   NaN
# ...          ...   ...
# 2086         NaN   NaN
# 2096         NaN   NaN
# 2103         NaN   NaN
# 2125         NaN   NaN
# 2131         NaN   NaN
#
# [195 rows x 18 columns]

# %%
#If both beds and Bath have 0, it shows the property is empty. Remove such rows
df = df.drop(zero_beds_baths.index)

# Reset the index, if needed
df.reset_index(drop=True, inplace=True)

# %%
# Remove the measurement units of "Area_Sqft"
df['Area_Sqft'] = pd.to_numeric(df['Area_Sqft'].str.replace(' Sq ft', '', regex=False).str.replace(',', ''), errors='coerce').astype(float).astype('Int64', errors='ignore')

# Remove the measurement units of "Price"
df['Price'] = pd.to_numeric(df['Price'].str.replace('[\$,]', '', regex=True), errors='coerce').astype(float).astype('Int64', errors='ignore')

# Remove the measurement units of "Time_on_Redfin(days)"
df['Time_on_Redfin(days)'] = pd.to_numeric(df['Time_on_Redfin(days)'].str.replace(' days?', '', regex=True), errors='coerce').astype(float).astype('Int64', errors='ignore')

df
# Out:
#                                      Address    Price Beds Baths  Area_Sqft  \
# 0         41247 Apricot Ln,Fremont, CA 94539  1999888    4     2       1698
# 1          34116 Pavia Ter,Fremont, CA 94555  1180000    3   3.5       1387
# 2             36778 Oak St,Fremont, CA 94536  1499888    3     2       1610
# 3      4046 Abbey Ter #113,Fremont, CA 94536   598500    2     2        823
# 4          345 Torrano Cmn,Fremont, CA 94536   799888    2     1       1016
# ...                                      ...      ...  ...   ...        ...
# 1932   148 Bepler St,San Francisco, CA 94112   562900    2     1        786
# 1933  151 Wellington Ave,Daly City, CA 94014  1150000    2     1        980
# 1934  127 Wellington Ave,Daly City, CA 94014   850000    2     1       1270
# 1935    475 Irvington St,Daly City, CA 94014   875000    2     1        980
# 1936     68 Lausanne Ave,DALY CITY, CA 94014  1250000    5     4       4348
#
#            City  Zipcode  Time_on_Redfin(days)              Property Type  \
# 0       Fremont    94539                     5  Single Family Residential
# 1       Fremont    94555                     1                      Condo
# 2       Fremont    94536                     1  Single Family Residential
# 3       Fremont    94536                     1                      Condo
# 4       Fremont    94536                     1                  Townhouse
# ...         ...      ...                   ...                        ...
# 1932  Daly City    94112                   255  Single Family Residential
# 1933  Daly City    94014                   332  Single Family Residential
# 1934  Daly City    94014                   332  Single Family Residential
# 1935  Daly City    94014                   332  Single Family Residential
# 1936  Daly City    94014                   375                    Triplex
#
#       Year_built        Community  Lot_Size_Sqft Est_Monthly_Payt  \
# 0         1960.0          FREMONT  6,720 Sq. Ft.          $14,526
# 1         2012.0   ARDENWOOD AREA     0.91 Acres           $8,855
# 2         1961.0        FAIR OAKS  6,978 Sq. Ft.          $10,894
# 3         1986.0     CENTRAL PARK     0.58 Acres           $4,757
# 4         1975.0  NILES THE TREES  2,448 Sq. Ft.           $6,150
# ...          ...              ...            ...              ...
# 1932      1927.0    San Francisco  2,500 Sq. Ft.           $4,089
# 1933      1912.0        Daly City  3,597 Sq. Ft.           $8,353
# 1934      1912.0        Daly City  3,094 Sq. Ft.           $6,174
# 1935      1912.0        Daly City  1,850 Sq. Ft.           $6,356
# 1936      1965.0        DALY CITY  2,500 Sq. Ft.           $9,079
#
#      Est_Redfin_Price Price/Sq.Ft. Buyer_Agent_Commission    HOA_Dues  \
# 0          $2,134,398       $1,178                   2.5%         NaN
# 1          $1,161,551         $851                   2.5%  $284/month
# 2          $1,513,958         $932                   2.5%         NaN
# 3            $598,791         $727                   2.5%  $410/month
# 4            $798,177         $787                   2.5%  $340/month
# ...               ...          ...                    ...         ...
# 1932         $714,473         $716                    NaN         NaN
# 1933       $1,082,742       $1,173                    NaN         NaN
# 1934         $829,959         $669                    NaN         NaN
# 1935         $842,589         $893                    NaN         NaN
# 1936       $1,189,034         $287                   2.5%         NaN
#
#                    Style
# 0                    NaN
# 1           Contemporary
# 2                  Ranch
# 3           Contemporary
# 4                    NaN
# ...                  ...
# 1932                 NaN
# 1933  Traditional, Other
# 1934  Traditional, Other
# 1935         Traditional
# 1936                 NaN
#
# [1937 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1937 entries, 0 to 1936
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Address                 1937 non-null   object
#  1   Price                   1838 non-null   Int64
#  2   Beds                    1937 non-null   object
#  3   Baths                   1937 non-null   object
#  4   Area_Sqft               1937 non-null   Int64
#  5   City                    1937 non-null   object
#  6   Zipcode                 1937 non-null   int64
#  7   Time_on_Redfin(days)    1815 non-null   Int64
#  8   Property Type           1937 non-null   object
#  9   Year_built              1805 non-null   float64
#  10  Community               1877 non-null   object
#  11  Lot_Size_Sqft           1539 non-null   object
#  12  Est_Monthly_Payt        1935 non-null   object
#  13  Est_Redfin_Price        1660 non-null   object
#  14  Price/Sq.Ft.            1937 non-null   object
#  15  Buyer_Agent_Commission  1395 non-null   object
#  16  HOA_Dues                686 non-null    object
#  17  Style                   896 non-null    object
# dtypes: Int64(3), float64(1), int64(1), object(13)
# memory usage: 278.2+ KB

# %%
# Replace Time_on_Redfin(days) null values as 0 (assuming the entries for these properties are new)
df['Time_on_Redfin(days)'].fillna(0,inplace=True)
df
# Out:
#                                      Address    Price Beds Baths  Area_Sqft  \
# 0         41247 Apricot Ln,Fremont, CA 94539  1999888    4     2       1698
# 1          34116 Pavia Ter,Fremont, CA 94555  1180000    3   3.5       1387
# 2             36778 Oak St,Fremont, CA 94536  1499888    3     2       1610
# 3      4046 Abbey Ter #113,Fremont, CA 94536   598500    2     2        823
# 4          345 Torrano Cmn,Fremont, CA 94536   799888    2     1       1016
# ...                                      ...      ...  ...   ...        ...
# 1932   148 Bepler St,San Francisco, CA 94112   562900    2     1        786
# 1933  151 Wellington Ave,Daly City, CA 94014  1150000    2     1        980
# 1934  127 Wellington Ave,Daly City, CA 94014   850000    2     1       1270
# 1935    475 Irvington St,Daly City, CA 94014   875000    2     1        980
# 1936     68 Lausanne Ave,DALY CITY, CA 94014  1250000    5     4       4348
#
#            City  Zipcode  Time_on_Redfin(days)              Property Type  \
# 0       Fremont    94539                     5  Single Family Residential
# 1       Fremont    94555                     1                      Condo
# 2       Fremont    94536                     1  Single Family Residential
# 3       Fremont    94536                     1                      Condo
# 4       Fremont    94536                     1                  Townhouse
# ...         ...      ...                   ...                        ...
# 1932  Daly City    94112                   255  Single Family Residential
# 1933  Daly City    94014                   332  Single Family Residential
# 1934  Daly City    94014                   332  Single Family Residential
# 1935  Daly City    94014                   332  Single Family Residential
# 1936  Daly City    94014                   375                    Triplex
#
#       Year_built        Community  Lot_Size_Sqft Est_Monthly_Payt  \
# 0         1960.0          FREMONT  6,720 Sq. Ft.          $14,526
# 1         2012.0   ARDENWOOD AREA     0.91 Acres           $8,855
# 2         1961.0        FAIR OAKS  6,978 Sq. Ft.          $10,894
# 3         1986.0     CENTRAL PARK     0.58 Acres           $4,757
# 4         1975.0  NILES THE TREES  2,448 Sq. Ft.           $6,150
# ...          ...              ...            ...              ...
# 1932      1927.0    San Francisco  2,500 Sq. Ft.           $4,089
# 1933      1912.0        Daly City  3,597 Sq. Ft.           $8,353
# 1934      1912.0        Daly City  3,094 Sq. Ft.           $6,174
# 1935      1912.0        Daly City  1,850 Sq. Ft.           $6,356
# 1936      1965.0        DALY CITY  2,500 Sq. Ft.           $9,079
#
#      Est_Redfin_Price Price/Sq.Ft. Buyer_Agent_Commission    HOA_Dues  \
# 0          $2,134,398       $1,178                   2.5%         NaN
# 1          $1,161,551         $851                   2.5%  $284/month
# 2          $1,513,958         $932                   2.5%         NaN
# 3            $598,791         $727                   2.5%  $410/month
# 4            $798,177         $787                   2.5%  $340/month
# ...               ...          ...                    ...         ...
# 1932         $714,473         $716                    NaN         NaN
# 1933       $1,082,742       $1,173                    NaN         NaN
# 1934         $829,959         $669                    NaN         NaN
# 1935         $842,589         $893                    NaN         NaN
# 1936       $1,189,034         $287                   2.5%         NaN
#
#                    Style
# 0                    NaN
# 1           Contemporary
# 2                  Ranch
# 3           Contemporary
# 4                    NaN
# ...                  ...
# 1932                 NaN
# 1933  Traditional, Other
# 1934  Traditional, Other
# 1935         Traditional
# 1936                 NaN
#
# [1937 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# Address                      0
# Price                       99
# Beds                         0
# Baths                        0
# Area_Sqft                    0
# City                         0
# Zipcode                      0
# Time_on_Redfin(days)         0
# Property Type                0
# Year_built                 132
# Community                   60
# Lot_Size_Sqft              398
# Est_Monthly_Payt             2
# Est_Redfin_Price           277
# Price/Sq.Ft.                 0
# Buyer_Agent_Commission     542
# HOA_Dues                  1251
# Style                     1041
# dtype: int64

# %%
# Treat NA Values in 'Price'
mean_price = df['Price'].mean().astype(int)

# Replace the NA values in the "Price" column with the mean value
df['Price'].fillna(mean_price, inplace=True)

# %%
# Treat NA Values in 'Price'
df['Year_built'].fillna('Unknown', inplace=True)

# %%
# Treat NA Values in 'Community'
df['Community'].fillna(df['City'], inplace=True)

# %%
# Treat NA Values in 'Price'
df['Style'].fillna('Unknown', inplace=True)
df
# Out:
#                                      Address    Price Beds Baths  Area_Sqft  \
# 0         41247 Apricot Ln,Fremont, CA 94539  1999888    4     2       1698
# 1          34116 Pavia Ter,Fremont, CA 94555  1180000    3   3.5       1387
# 2             36778 Oak St,Fremont, CA 94536  1499888    3     2       1610
# 3      4046 Abbey Ter #113,Fremont, CA 94536   598500    2     2        823
# 4          345 Torrano Cmn,Fremont, CA 94536   799888    2     1       1016
# ...                                      ...      ...  ...   ...        ...
# 1932   148 Bepler St,San Francisco, CA 94112   562900    2     1        786
# 1933  151 Wellington Ave,Daly City, CA 94014  1150000    2     1        980
# 1934  127 Wellington Ave,Daly City, CA 94014   850000    2     1       1270
# 1935    475 Irvington St,Daly City, CA 94014   875000    2     1        980
# 1936     68 Lausanne Ave,DALY CITY, CA 94014  1250000    5     4       4348
#
#            City  Zipcode  Time_on_Redfin(days)              Property Type  \
# 0       Fremont    94539                     5  Single Family Residential
# 1       Fremont    94555                     1                      Condo
# 2       Fremont    94536                     1  Single Family Residential
# 3       Fremont    94536                     1                      Condo
# 4       Fremont    94536                     1                  Townhouse
# ...         ...      ...                   ...                        ...
# 1932  Daly City    94112                   255  Single Family Residential
# 1933  Daly City    94014                   332  Single Family Residential
# 1934  Daly City    94014                   332  Single Family Residential
# 1935  Daly City    94014                   332  Single Family Residential
# 1936  Daly City    94014                   375                    Triplex
#
#      Year_built        Community  Lot_Size_Sqft Est_Monthly_Payt  \
# 0        1960.0          FREMONT  6,720 Sq. Ft.          $14,526
# 1        2012.0   ARDENWOOD AREA     0.91 Acres           $8,855
# 2        1961.0        FAIR OAKS  6,978 Sq. Ft.          $10,894
# 3        1986.0     CENTRAL PARK     0.58 Acres           $4,757
# 4        1975.0  NILES THE TREES  2,448 Sq. Ft.           $6,150
# ...         ...              ...            ...              ...
# 1932     1927.0    San Francisco  2,500 Sq. Ft.           $4,089
# 1933     1912.0        Daly City  3,597 Sq. Ft.           $8,353
# 1934     1912.0        Daly City  3,094 Sq. Ft.           $6,174
# 1935     1912.0        Daly City  1,850 Sq. Ft.           $6,356
# 1936     1965.0        DALY CITY  2,500 Sq. Ft.           $9,079
#
#      Est_Redfin_Price Price/Sq.Ft. Buyer_Agent_Commission    HOA_Dues  \
# 0          $2,134,398       $1,178                   2.5%         NaN
# 1          $1,161,551         $851                   2.5%  $284/month
# 2          $1,513,958         $932                   2.5%         NaN
# 3            $598,791         $727                   2.5%  $410/month
# 4            $798,177         $787                   2.5%  $340/month
# ...               ...          ...                    ...         ...
# 1932         $714,473         $716                    NaN         NaN
# 1933       $1,082,742       $1,173                    NaN         NaN
# 1934         $829,959         $669                    NaN         NaN
# 1935         $842,589         $893                    NaN         NaN
# 1936       $1,189,034         $287                   2.5%         NaN
#
#                    Style
# 0                Unknown
# 1           Contemporary
# 2                  Ranch
# 3           Contemporary
# 4                Unknown
# ...                  ...
# 1932             Unknown
# 1933  Traditional, Other
# 1934  Traditional, Other
# 1935         Traditional
# 1936             Unknown
#
# [1937 rows x 18 columns]

# %%
# Treat NA Values in 'Lot_Size_Sqft'

# Convert Acres to Sq. Ft.
def acres_to_sqft(value):
    if isinstance(value, float) and np.isnan(value):
        return np.nan
    elif isinstance(value, float):
        return int(value)
    elif 'Acres' in value:
        acres = float(value.split()[0].replace(',', ''))
        sqft = acres * 43560  # 1 Acre = 43,560 Sq. Ft.
        return int(sqft)
    elif 'Sq. Ft.' in value:
        sqft = float(value.split()[0].replace(',', ''))
        return int(sqft)
    else:
        return None

df['Lot_Size_Sqft'] = df['Lot_Size_Sqft'].apply(acres_to_sqft)
df
# Out:
#                                      Address    Price Beds Baths  Area_Sqft  \
# 0         41247 Apricot Ln,Fremont, CA 94539  1999888    4     2       1698
# 1          34116 Pavia Ter,Fremont, CA 94555  1180000    3   3.5       1387
# 2             36778 Oak St,Fremont, CA 94536  1499888    3     2       1610
# 3      4046 Abbey Ter #113,Fremont, CA 94536   598500    2     2        823
# 4          345 Torrano Cmn,Fremont, CA 94536   799888    2     1       1016
# ...                                      ...      ...  ...   ...        ...
# 1932   148 Bepler St,San Francisco, CA 94112   562900    2     1        786
# 1933  151 Wellington Ave,Daly City, CA 94014  1150000    2     1        980
# 1934  127 Wellington Ave,Daly City, CA 94014   850000    2     1       1270
# 1935    475 Irvington St,Daly City, CA 94014   875000    2     1        980
# 1936     68 Lausanne Ave,DALY CITY, CA 94014  1250000    5     4       4348
#
#            City  Zipcode  Time_on_Redfin(days)              Property Type  \
# 0       Fremont    94539                     5  Single Family Residential
# 1       Fremont    94555                     1                      Condo
# 2       Fremont    94536                     1  Single Family Residential
# 3       Fremont    94536                     1                      Condo
# 4       Fremont    94536                     1                  Townhouse
# ...         ...      ...                   ...                        ...
# 1932  Daly City    94112                   255  Single Family Residential
# 1933  Daly City    94014                   332  Single Family Residential
# 1934  Daly City    94014                   332  Single Family Residential
# 1935  Daly City    94014                   332  Single Family Residential
# 1936  Daly City    94014                   375                    Triplex
#
#      Year_built        Community  Lot_Size_Sqft Est_Monthly_Payt  \
# 0        1960.0          FREMONT         6720.0          $14,526
# 1        2012.0   ARDENWOOD AREA        39639.0           $8,855
# 2        1961.0        FAIR OAKS         6978.0          $10,894
# 3        1986.0     CENTRAL PARK        25264.0           $4,757
# 4        1975.0  NILES THE TREES         2448.0           $6,150
# ...         ...              ...            ...              ...
# 1932     1927.0    San Francisco         2500.0           $4,089
# 1933     1912.0        Daly City         3597.0           $8,353
# 1934     1912.0        Daly City         3094.0           $6,174
# 1935     1912.0        Daly City         1850.0           $6,356
# 1936     1965.0        DALY CITY         2500.0           $9,079
#
#      Est_Redfin_Price Price/Sq.Ft. Buyer_Agent_Commission    HOA_Dues  \
# 0          $2,134,398       $1,178                   2.5%         NaN
# 1          $1,161,551         $851                   2.5%  $284/month
# 2          $1,513,958         $932                   2.5%         NaN
# 3            $598,791         $727                   2.5%  $410/month
# 4            $798,177         $787                   2.5%  $340/month
# ...               ...          ...                    ...         ...
# 1932         $714,473         $716                    NaN         NaN
# 1933       $1,082,742       $1,173                    NaN         NaN
# 1934         $829,959         $669                    NaN         NaN
# 1935         $842,589         $893                    NaN         NaN
# 1936       $1,189,034         $287                   2.5%         NaN
#
#                    Style
# 0                Unknown
# 1           Contemporary
# 2                  Ranch
# 3           Contemporary
# 4                Unknown
# ...                  ...
# 1932             Unknown
# 1933  Traditional, Other
# 1934  Traditional, Other
# 1935         Traditional
# 1936             Unknown
#
# [1937 rows x 18 columns]

# %%
# Replace NaN values with the mean value in "Lot_Size_Sqft" column
mean_lot_size_sqft = df['Lot_Size_Sqft'].mean()
df['Lot_Size_Sqft'].fillna(mean_lot_size_sqft, inplace=True)
df['Lot_Size_Sqft'] = df['Lot_Size_Sqft'].astype(int)

# %%
# Treat NA Values in 'Est_Redfin_Price' and 'Est_Monthly_Payt'
# Remove the measurement units of "Est_Redfin_Price"
df['Est_Redfin_Price'] = pd.to_numeric(df['Est_Redfin_Price'].str.replace('[\$,]', '', regex=True), errors='coerce').astype(float).astype('Int64', errors='ignore')

# Remove the measurement units of "Est_Monthly_Payt"
df['Est_Monthly_Payt'] = pd.to_numeric(df['Est_Monthly_Payt'].str.replace('[\$,]', '', regex=True), errors='coerce').astype(float).astype('Int64', errors='ignore')
df
# Out:
#                                      Address    Price Beds Baths  Area_Sqft  \
# 0         41247 Apricot Ln,Fremont, CA 94539  1999888    4     2       1698
# 1          34116 Pavia Ter,Fremont, CA 94555  1180000    3   3.5       1387
# 2             36778 Oak St,Fremont, CA 94536  1499888    3     2       1610
# 3      4046 Abbey Ter #113,Fremont, CA 94536   598500    2     2        823
# 4          345 Torrano Cmn,Fremont, CA 94536   799888    2     1       1016
# ...                                      ...      ...  ...   ...        ...
# 1932   148 Bepler St,San Francisco, CA 94112   562900    2     1        786
# 1933  151 Wellington Ave,Daly City, CA 94014  1150000    2     1        980
# 1934  127 Wellington Ave,Daly City, CA 94014   850000    2     1       1270
# 1935    475 Irvington St,Daly City, CA 94014   875000    2     1        980
# 1936     68 Lausanne Ave,DALY CITY, CA 94014  1250000    5     4       4348
#
#            City  Zipcode  Time_on_Redfin(days)              Property Type  \
# 0       Fremont    94539                     5  Single Family Residential
# 1       Fremont    94555                     1                      Condo
# 2       Fremont    94536                     1  Single Family Residential
# 3       Fremont    94536                     1                      Condo
# 4       Fremont    94536                     1                  Townhouse
# ...         ...      ...                   ...                        ...
# 1932  Daly City    94112                   255  Single Family Residential
# 1933  Daly City    94014                   332  Single Family Residential
# 1934  Daly City    94014                   332  Single Family Residential
# 1935  Daly City    94014                   332  Single Family Residential
# 1936  Daly City    94014                   375                    Triplex
#
#      Year_built        Community  Lot_Size_Sqft  Est_Monthly_Payt  \
# 0        1960.0          FREMONT           6720             14526
# 1        2012.0   ARDENWOOD AREA          39639              8855
# 2        1961.0        FAIR OAKS           6978             10894
# 3        1986.0     CENTRAL PARK          25264              4757
# 4        1975.0  NILES THE TREES           2448              6150
# ...         ...              ...            ...               ...
# 1932     1927.0    San Francisco           2500              4089
# 1933     1912.0        Daly City           3597              8353
# 1934     1912.0        Daly City           3094              6174
# 1935     1912.0        Daly City           1850              6356
# 1936     1965.0        DALY CITY           2500              9079
#
#       Est_Redfin_Price Price/Sq.Ft. Buyer_Agent_Commission    HOA_Dues  \
# 0              2134398       $1,178                   2.5%         NaN
# 1              1161551         $851                   2.5%  $284/month
# 2              1513958         $932                   2.5%         NaN
# 3               598791         $727                   2.5%  $410/month
# 4               798177         $787                   2.5%  $340/month
# ...                ...          ...                    ...         ...
# 1932            714473         $716                    NaN         NaN
# 1933           1082742       $1,173                    NaN         NaN
# 1934            829959         $669                    NaN         NaN
# 1935            842589         $893                    NaN         NaN
# 1936           1189034         $287                   2.5%         NaN
#
#                    Style
# 0                Unknown
# 1           Contemporary
# 2                  Ranch
# 3           Contemporary
# 4                Unknown
# ...                  ...
# 1932             Unknown
# 1933  Traditional, Other
# 1934  Traditional, Other
# 1935         Traditional
# 1936             Unknown
#
# [1937 rows x 18 columns]

# %%
# Replace NaN values with the mean value in "Est_Redfin_Price" column
mean_est_redfin_price = df['Est_Redfin_Price'].mean().astype(int)
df['Est_Redfin_Price'].fillna(mean_est_redfin_price, inplace=True)

# Replace NaN values with the mean value in "Est_Monthly_Payt" column
mean_est_monthly_price = df['Est_Monthly_Payt'].mean().astype(int)
df['Est_Monthly_Payt'].fillna(mean_est_monthly_price, inplace=True)

# %%
# Treat NA Values in 'HOA_Dues'
df['HOA_Dues'] = df['HOA_Dues'].str.replace('[,$/month]', '', regex=True)
df['HOA_Dues'].fillna(0,inplace=True)
df['HOA_Dues'] = df['HOA_Dues'].astype(float)

# %%
# Treat NA Values in 'Buyer_Agent_Commission'
df['Buyer_Agent_Commission'] = df['Buyer_Agent_Commission'].str.rstrip('%')

# Convert the column to numeric
df['Buyer_Agent_Commission'] = pd.to_numeric(df['Buyer_Agent_Commission'], errors='coerce')

# Calculate the mean commission excluding NaN values
mean_commission = df['Buyer_Agent_Commission'].mean()

# Replace null values with the mean
df['Buyer_Agent_Commission'].fillna(mean_commission, inplace=True)

# %%
df['Price/Sq.Ft.'] = df['Price/Sq.Ft.'].str.replace(',', '').str.replace('$', '').astype(int)
# Out:
# /var/folders/f4/x9b2p2t11s59gnlnjzbvsr940000gn/T/ipykernel_20726/4246662672.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price/Sq.Ft.'] = df['Price/Sq.Ft.'].str.replace(',', '').str.replace('$', '').astype(int)

# %%
df['Buyer_Agent_Commission'] = df['Buyer_Agent_Commission'].round(0).astype(int)

# %%
df['HOA_Dues'] = df['HOA_Dues'].astype(int)

# %%
# Remove decimal from year
def convert_to_int(value):
    try:
        return int(float(value))
    except (ValueError, TypeError):
        return value

df['Year_built'] = df['Year_built'].apply(convert_to_int)
df
# Out:
#                                      Address    Price Beds Baths  Area_Sqft  \
# 0         41247 Apricot Ln,Fremont, CA 94539  1999888    4     2       1698
# 1          34116 Pavia Ter,Fremont, CA 94555  1180000    3   3.5       1387
# 2             36778 Oak St,Fremont, CA 94536  1499888    3     2       1610
# 3      4046 Abbey Ter #113,Fremont, CA 94536   598500    2     2        823
# 4          345 Torrano Cmn,Fremont, CA 94536   799888    2     1       1016
# ...                                      ...      ...  ...   ...        ...
# 1932   148 Bepler St,San Francisco, CA 94112   562900    2     1        786
# 1933  151 Wellington Ave,Daly City, CA 94014  1150000    2     1        980
# 1934  127 Wellington Ave,Daly City, CA 94014   850000    2     1       1270
# 1935    475 Irvington St,Daly City, CA 94014   875000    2     1        980
# 1936     68 Lausanne Ave,DALY CITY, CA 94014  1250000    5     4       4348
#
#            City  Zipcode  Time_on_Redfin(days)              Property Type  \
# 0       Fremont    94539                     5  Single Family Residential
# 1       Fremont    94555                     1                      Condo
# 2       Fremont    94536                     1  Single Family Residential
# 3       Fremont    94536                     1                      Condo
# 4       Fremont    94536                     1                  Townhouse
# ...         ...      ...                   ...                        ...
# 1932  Daly City    94112                   255  Single Family Residential
# 1933  Daly City    94014                   332  Single Family Residential
# 1934  Daly City    94014                   332  Single Family Residential
# 1935  Daly City    94014                   332  Single Family Residential
# 1936  Daly City    94014                   375                    Triplex
#
#      Year_built        Community  Lot_Size_Sqft  Est_Monthly_Payt  \
# 0          1960          FREMONT           6720             14526
# 1          2012   ARDENWOOD AREA          39639              8855
# 2          1961        FAIR OAKS           6978             10894
# 3          1986     CENTRAL PARK          25264              4757
# 4          1975  NILES THE TREES           2448              6150
# ...         ...              ...            ...               ...
# 1932       1927    San Francisco           2500              4089
# 1933       1912        Daly City           3597              8353
# 1934       1912        Daly City           3094              6174
# 1935       1912        Daly City           1850              6356
# 1936       1965        DALY CITY           2500              9079
#
#       Est_Redfin_Price  Price/Sq.Ft.  Buyer_Agent_Commission  HOA_Dues  \
# 0              2134398          1178                       2         0
# 1              1161551           851                       2       284
# 2              1513958           932                       2         0
# 3               598791           727                       2       410
# 4               798177           787                       2       340
# ...                ...           ...                     ...       ...
# 1932            714473           716                       2         0
# 1933           1082742          1173                       2         0
# 1934            829959           669                       2         0
# 1935            842589           893                       2         0
# 1936           1189034           287                       2         0
#
#                    Style
# 0                Unknown
# 1           Contemporary
# 2                  Ranch
# 3           Contemporary
# 4                Unknown
# ...                  ...
# 1932             Unknown
# 1933  Traditional, Other
# 1934  Traditional, Other
# 1935         Traditional
# 1936             Unknown
#
# [1937 rows x 18 columns]

# %%
# Recheck Null Values
df.isnull().sum()
# Out:
# Address                   0
# Price                     0
# Beds                      0
# Baths                     0
# Area_Sqft                 0
# City                      0
# Zipcode                   0
# Time_on_Redfin(days)      0
# Property Type             0
# Year_built                0
# Community                 0
# Lot_Size_Sqft             0
# Est_Monthly_Payt          0
# Est_Redfin_Price          0
# Price/Sq.Ft.              0
# Buyer_Agent_Commission    0
# HOA_Dues                  0
# Style                     0
# dtype: int64

# %%
df.to_csv('cleaned_sales_data.csv', sep=',')
