# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as BS
import re
import math
import pandas as pd

# %%
## Function for creating the soup obj
def get_soup_for_url(url):
    htmlfile = urlopen(url) 
    soup = BS(htmlfile,'html.parser')
    return soup

# %%
## Function for geting the house links and other meta data by iterating from the list
def get_home_links(soup, rent_sale, city):
    
    # Using the home views container to get the list of houses in the page
    parent = soup.find('div',{'class':'HomeViews'})
    
    ## The redfine shows the each house as Card and each card has the unique ID. it ranges from 0-39 (max)
    # Each id value has the prefix of MapHomeCard_<ID>, hence usign the prefix to fetch all of cards in the page
    properties = parent.findChildren('div', {'id':re.compile('^MapHomeCard_')})
    
    property_list = list({})
    
    ## Iterating the house cards and creatng dictionary with house properties
    for property in properties:
        entry = {}
        entry['price'] = property.find('span', {'class':'homecardV2Price'}).text
        if("Sale" ==  rent_sale):
            entry['address'] = property.find('span', {'class':'collapsedAddress primaryLine'}).text
        else:
            try:
                entry['address'] = property.find('span', {'class':'propertyName collapsed'}).text
            except:
                entry['address'] = property.find('span', {'class':'collapsedAddress primaryLine'}).text
        entry['link'] = property.a['href']
        entry['zipcode'] = entry['address'][-5:]
        entry['city'] = city
        entry['rent_or_sale'] = rent_sale
        property_list.append(entry)

    
    return property_list

# %%
df = pd.read_csv ('redfine_url_links_citywise.csv')
df
# Out:
#     no                                                url  \
# 0    1        https://www.redfin.com/city/6671/CA/Fremont
# 1    2  https://www.redfin.com/city/6671/CA/Fremont/ap...
# 2    3      https://www.redfin.com/city/17420/CA/San-Jose
# 3    4  https://www.redfin.com/city/17420/CA/San-Jose/...
# 4    5  https://www.redfin.com/city/8439/CA/Hayward/ap...
# 5    6        https://www.redfin.com/city/8439/CA/Hayward
# 6    7    https://www.redfin.com/city/20321/CA/Union-City
# 7    8  https://www.redfin.com/city/20321/CA/Union-Cit...
# 8    9   https://www.redfin.com/city/17447/CA/San-Leandro
# 9   10  https://www.redfin.com/city/17447/CA/San-Leand...
# 10  11  https://www.redfin.com/city/13654/CA/Oakland/a...
# 11  12       https://www.redfin.com/city/13654/CA/Oakland
# 12  13       https://www.redfin.com/city/1590/CA/Berkeley
# 13  14  https://www.redfin.com/city/1590/CA/Berkeley/a...
# 14  15  https://www.redfin.com/city/15629/CA/Richmond/...
# 15  16      https://www.redfin.com/city/15629/CA/Richmond
# 16  17    https://www.redfin.com/city/17518/CA/San-Rafael
# 17  18  https://www.redfin.com/city/17518/CA/San-Rafae...
# 18  19   https://www.redfin.com/city/12192/CA/Mill-Valley
# 19  20  https://www.redfin.com/city/12192/CA/Mill-Vall...
# 20  21     https://www.redfin.com/city/17978/CA/Sausalito
# 21  22  https://www.redfin.com/city/17978/CA/Sausalito...
# 22  23  https://www.redfin.com/city/20371/CA/Vallejo/a...
# 23  24       https://www.redfin.com/city/20371/CA/Vallejo
# 24  25  https://www.redfin.com/city/12739/CA/Mountain-...
# 25  26  https://www.redfin.com/city/12739/CA/Mountain-...
# 26  27  https://www.redfin.com/city/14325/CA/Palo-Alto...
# 27  28     https://www.redfin.com/city/14325/CA/Palo-Alto
# 28  29  https://www.redfin.com/city/15525/CA/Redwood-City
# 29  30  https://www.redfin.com/city/15525/CA/Redwood-C...
# 30  31  https://www.redfin.com/city/17490/CA/San-Mateo...
# 31  32     https://www.redfin.com/city/17490/CA/San-Mateo
# 32  33      https://www.redfin.com/city/12130/CA/Millbrae
# 33  34  https://www.redfin.com/city/12130/CA/Millbrae/...
# 34  35  https://www.redfin.com/city/18672/CA/South-San...
# 35  36  https://www.redfin.com/city/18672/CA/South-San...
# 36  37      https://www.redfin.com/city/4636/CA/Daly-City
# 37  38  https://www.redfin.com/city/4636/CA/Daly-City/...
#
#                    city rent_sale
# 0               Fremont      Sale
# 1               Fremont      Rent
# 2              San Jose      Sale
# 3              San Jose      Rent
# 4               Hayward      Rent
# 5               Hayward      Sale
# 6            Union City      Sale
# 7            Union City      Rent
# 8           San Leandro      Sale
# 9           San Leandro      Rent
# 10              Oakland      Rent
# 11              Oakland      Sale
# 12             Berkeley      Sale
# 13             Berkeley      Rent
# 14             Richmond      Rent
# 15             Richmond      Sale
# 16           San Rafael      Sale
# 17           San Rafael      Rent
# 18          Mill Valley      Sale
# 19          Mill Valley      Rent
# 20            Sausalito      Sale
# 21            Sausalito      Rent
# 22              Vallejo      Rent
# 23              Vallejo      Sale
# 24        Mountain View      Sale
# 25        Mountain View      Rent
# 26            Palo Alto      Rent
# 27            Palo Alto      Sale
# 28         Redwood City      Sale
# 29         Redwood City      Rent
# 30            San Mateo      Rent
# 31            San Mateo      Sale
# 32             Millbrae      Sale
# 33             Millbrae      Rent
# 34  South San Francisco      Rent
# 35  South San Francisco      Sale
# 36            Daly City      Sale
# 37            Daly City      Rent

# %%
target_cities =df.to_dict('records')

# %%
## The master list would be holding the house links of all the url given in the urls list


prop_master_list = {'Sale' : list({}), 'Rent': list({})}

for  target in target_cities:
    print(target)
    url = target['url']
    city = target['city']
    rent_sale = target['rent_sale']
    ## Getting the first (40) page homes
    soup = get_soup_for_url(url)
    ## Appendign the home links to the master list
    
    prop_master_list[rent_sale] =  prop_master_list[rent_sale]+ get_home_links(soup, rent_sale, city)
    
    ## Getting the total house count to make further calls on the same target area
    summary = soup.find('div',{'class':'homes summary'}).get_text()
     ## Redfine has the default 40 homes per page settings
    # So the total # of pages count could be obtained by dividing the total home count by 40 
    regx = '(\d+)  apartments for rent'
    if "Sale" == rent_sale:
        regx = '40 of (\d+)'
    
    try:
        total_house = int(re.findall(regx,summary)[0])
    except:
        total_house = int(re.findall('(\d+)  homes',summary)[0])
            
    page_count = math.ceil(total_house/40)
    
    ## Iterating the each page and creating the soup object for each page and parsing the links
    # Each iteration finally appends the list of homes to the master list
    for i in range(2, page_count+1):
        soup = get_soup_for_url(url+'/page-'+str(i))
        ## Appending the each page house list to the master
        prop_master_list[rent_sale] =  prop_master_list[rent_sale]+ get_home_links(soup,rent_sale,city)
# Out:
# {'no': 1, 'url': 'https://www.redfin.com/city/6671/CA/Fremont', 'city': 'Fremont', 'rent_sale': 'Sale'}
# {'no': 2, 'url': 'https://www.redfin.com/city/6671/CA/Fremont/apartments-for-rent', 'city': 'Fremont', 'rent_sale': 'Rent'}
# {'no': 3, 'url': 'https://www.redfin.com/city/17420/CA/San-Jose', 'city': 'San Jose', 'rent_sale': 'Sale'}
# {'no': 4, 'url': 'https://www.redfin.com/city/17420/CA/San-Jose/apartments-for-rent', 'city': 'San Jose', 'rent_sale': 'Rent'}
# {'no': 5, 'url': 'https://www.redfin.com/city/8439/CA/Hayward/apartments-for-rent', 'city': 'Hayward', 'rent_sale': 'Rent'}
# {'no': 6, 'url': 'https://www.redfin.com/city/8439/CA/Hayward', 'city': 'Hayward', 'rent_sale': 'Sale'}
# {'no': 7, 'url': 'https://www.redfin.com/city/20321/CA/Union-City', 'city': 'Union City', 'rent_sale': 'Sale'}
# {'no': 8, 'url': 'https://www.redfin.com/city/20321/CA/Union-City/apartments-for-rent', 'city': 'Union City', 'rent_sale': 'Rent'}
# {'no': 9, 'url': 'https://www.redfin.com/city/17447/CA/San-Leandro', 'city': 'San Leandro', 'rent_sale': 'Sale'}
# {'no': 10, 'url': 'https://www.redfin.com/city/17447/CA/San-Leandro/apartments-for-rent', 'city': 'San Leandro', 'rent_sale': 'Rent'}
# {'no': 11, 'url': 'https://www.redfin.com/city/13654/CA/Oakland/apartments-for-rent', 'city': 'Oakland', 'rent_sale': 'Rent'}
# {'no': 12, 'url': 'https://www.redfin.com/city/13654/CA/Oakland', 'city': 'Oakland', 'rent_sale': 'Sale'}
# {'no': 13, 'url': 'https://www.redfin.com/city/1590/CA/Berkeley', 'city': 'Berkeley', 'rent_sale': 'Sale'}
# {'no': 14, 'url': 'https://www.redfin.com/city/1590/CA/Berkeley/apartments-for-rent', 'city': 'Berkeley', 'rent_sale': 'Rent'}
# {'no': 15, 'url': 'https://www.redfin.com/city/15629/CA/Richmond/apartments-for-rent', 'city': 'Richmond', 'rent_sale': 'Rent'}
# {'no': 16, 'url': 'https://www.redfin.com/city/15629/CA/Richmond', 'city': 'Richmond', 'rent_sale': 'Sale'}
# {'no': 17, 'url': 'https://www.redfin.com/city/17518/CA/San-Rafael', 'city': 'San Rafael', 'rent_sale': 'Sale'}
# {'no': 18, 'url': 'https://www.redfin.com/city/17518/CA/San-Rafael/apartments-for-rent', 'city': 'San Rafael', 'rent_sale': 'Rent'}
# {'no': 19, 'url': 'https://www.redfin.com/city/12192/CA/Mill-Valley', 'city': 'Mill Valley', 'rent_sale': 'Sale'}
# {'no': 20, 'url': 'https://www.redfin.com/city/12192/CA/Mill-Valley/apartments-for-rent', 'city': 'Mill Valley', 'rent_sale': 'Rent'}
# {'no': 21, 'url': 'https://www.redfin.com/city/17978/CA/Sausalito', 'city': 'Sausalito', 'rent_sale': 'Sale'}
# {'no': 22, 'url': 'https://www.redfin.com/city/17978/CA/Sausalito/apartments-for-rent', 'city': 'Sausalito', 'rent_sale': 'Rent'}
# {'no': 23, 'url': 'https://www.redfin.com/city/20371/CA/Vallejo/apartments-for-rent', 'city': 'Vallejo', 'rent_sale': 'Rent'}
# {'no': 24, 'url': 'https://www.redfin.com/city/20371/CA/Vallejo', 'city': 'Vallejo', 'rent_sale': 'Sale'}
# {'no': 25, 'url': 'https://www.redfin.com/city/12739/CA/Mountain-View', 'city': 'Mountain View', 'rent_sale': 'Sale'}
# {'no': 26, 'url': 'https://www.redfin.com/city/12739/CA/Mountain-View/apartments-for-rent', 'city': 'Mountain View', 'rent_sale': 'Rent'}
# {'no': 27, 'url': 'https://www.redfin.com/city/14325/CA/Palo-Alto/apartments-for-rent', 'city': 'Palo Alto', 'rent_sale': 'Rent'}
# {'no': 28, 'url': 'https://www.redfin.com/city/14325/CA/Palo-Alto', 'city': 'Palo Alto', 'rent_sale': 'Sale'}
# {'no': 29, 'url': 'https://www.redfin.com/city/15525/CA/Redwood-City', 'city': 'Redwood City', 'rent_sale': 'Sale'}
# {'no': 30, 'url': 'https://www.redfin.com/city/15525/CA/Redwood-City/apartments-for-rent', 'city': 'Redwood City', 'rent_sale': 'Rent'}
# {'no': 31, 'url': 'https://www.redfin.com/city/17490/CA/San-Mateo/apartments-for-rent', 'city': 'San Mateo', 'rent_sale': 'Rent'}
# {'no': 32, 'url': 'https://www.redfin.com/city/17490/CA/San-Mateo', 'city': 'San Mateo', 'rent_sale': 'Sale'}
# {'no': 33, 'url': 'https://www.redfin.com/city/12130/CA/Millbrae', 'city': 'Millbrae', 'rent_sale': 'Sale'}
# {'no': 34, 'url': 'https://www.redfin.com/city/12130/CA/Millbrae/apartments-for-rent', 'city': 'Millbrae', 'rent_sale': 'Rent'}
# {'no': 35, 'url': 'https://www.redfin.com/city/18672/CA/South-San-Francisco/apartments-for-rent', 'city': 'South San Francisco', 'rent_sale': 'Rent'}
# {'no': 36, 'url': 'https://www.redfin.com/city/18672/CA/South-San-Francisco', 'city': 'South San Francisco', 'rent_sale': 'Sale'}
# {'no': 37, 'url': 'https://www.redfin.com/city/4636/CA/Daly-City', 'city': 'Daly City', 'rent_sale': 'Sale'}
# {'no': 38, 'url': 'https://www.redfin.com/city/4636/CA/Daly-City/apartments-for-rent', 'city': 'Daly City', 'rent_sale': 'Rent'}

# %%
df = pd.DataFrame(prop_master_list['Sale'])
df.to_csv('house_links_sale.csv', sep=',', encoding='utf-8')

# %%
df = pd.DataFrame(prop_master_list['Rent'])
df.to_csv('house_links_rent.csv', sep=',', encoding='utf-8')
